# %%
pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 90 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 662 kB 22.5 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 39.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 85 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 88 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 43.7 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 54.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 55.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 56.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 55.2 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp38-cp38-linux_x86_64.whl size=2700858 sha256=6d3b9e3bc932e68d87211ec8ba7ad041e392af12e11be01401279037ba0772fb
# ...

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from bertopic import BERTopic



from bertopic import BERTopic
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2") #use a pre-trained model: all-MiniLM-L6-v2

# %%
str = open('The_falling_sky.txt', 'r').read()
verses= str.split(".")

# %%
# check how text is split:  
#print(verses[57])
# Out:
# In the end, all of the shamans will perish and the sky will collapse

# %%
import nltk, nltk.tokenize, nltk.corpus, nltk.stem
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords, wordnet

# %%
#remove stopwords
def remove_stopwords(text):
    no_stop = text.split()
    stopwordz = stopwords.words('english')
    for word in no_stop:
        for stopword in stopwordz:
            if word == stopword:
                no_stop.remove(word)
    return ' '.join(no_stop)

#remove punctuation
def strip_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    return ' '.join(tokenizer.tokenize(text))

#preprocess text
def preprocess(text):
    
    text_no_stopwords = remove_stopwords(text)
    text_no_punct = strip_punctuation(text_no_stopwords)
    return text_no_punct

#application of the function preprocess(text) to our corpus 
"""verses_no_punct=[]
for x in verses:
    x_preprocessed=preprocess(x)
    verses_no_punct.append(x_preprocessed)"""
# Out:
# 'verses_no_punct=[]\nfor x in verses:\n    x_preprocessed=preprocess(x)\n    verses_no_punct.append(x_preprocessed)'

# %%
topic_model.fit(verses)
#obtaining our model on the basis of the pre-trained model
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model.get_topic_freq() #get the frequency of topics: ignore topic -1 since it is an outlier
# Out:
#      Topic  Count
# 0       -1   5257
# 1        0    738
# 2        1    350
# 3        2    335
# 4        3    326
# ..     ...    ...
# 252    251     10
# 253    252     10
# 254    253     10
# 255    254     10
# 256    255     10
#
# [257 rows x 2 columns]

# %%
topic_model.visualize_topics() #distance between topics
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#get the complete list of words for each of the most frequent topics
i=0
while i<8:
  print(topic_model.get_topic(i))
  i+=1
# Out:
# [('white', 0.025539998527906033), ('people', 0.018080907076892125), ('land', 0.005921623203356127), ('not', 0.005514862258073617), ('do', 0.005407043400495442), ('merchandise', 0.005201414589654144), ('our', 0.00506465734880076), ('thought', 0.005015354957985888), ('words', 0.004987391906876237), ('forest', 0.004985342637191813)]
# [('shamans', 0.03332657246646679), ('shaman', 0.03144572194505128), ('great', 0.011299623322530157), ('become', 0.0077517640608940706), ('spirits', 0.007515915595142147), ('spirit', 0.0072150448093621965), ('house', 0.007189870087655143), ('shamanic', 0.006665680748744646), ('houses', 0.006620458045163317), ('death', 0.006206312528396923)]
# ...

# %% [markdown]
# # Finding Topics
# Now let's search for the topics connected to some concepts we want to analyze: we can find topics connected with a specific word and visualize their composition.

# %%
omama=topic_model.find_topics("omama")

# %%
for idx,topic in enumerate(omama[0]):
  print("topic",topic,topic_model.get_topic(topic))
# Out:
# topic 7 [('omama', 0.06375303393614111), ('created', 0.021111015612268913), ('metal', 0.016087168080151162), ('son', 0.011944433406814302), ('image', 0.01093005484911769), ('ancestors', 0.009264169951584036), ('beginning', 0.008502066406975541), ('taught', 0.007720290615869601), ('first', 0.006340160845091556), ('flight', 0.0059889958495317345)]
# topic 76 [('omama', 0.05216763358683444), ('xapiri', 0.031202468898009487), ('created', 0.019568580454467323), ('words', 0.014163451309749405), ('son', 0.013510154888817608), ('us', 0.010245367984664166), ('come', 0.009465659472686318), ('are', 0.00942119214521793), ('belong', 0.009129441576789694), ('who', 0.008569458253216266)]
# ...

# %%
teosi=topic_model.find_topics("teosi")

# %%
for idx,topic in enumerate(teosi[0]):
  print("topic", topic,topic_model.get_topic(topic))
# Out:
# topic 10 [('teosi', 0.08347068917115462), ('words', 0.015422542157252925), ('you', 0.012325824987279993), ('missionaries', 0.010842823495620985), ('us', 0.010002067563792493), ('xupari', 0.00927097852959184), ('will', 0.008940449617214028), ('your', 0.008930312401873726), ('created', 0.008357946786797075), ('we', 0.008316634474783452)]
# topic 75 [('índio', 0.26041162334012236), ('fundação', 0.23951730570599575), ('nacional', 0.23673783940011123), ('brasília', 0.12016534308252895), ('vista', 0.052741051504795196), ('do', 0.05255654786092916), ('boa', 0.05040954735416863), ('regional', 0.049749011122017385), ('delegacia', 0.045855076491573124), ('brasil', 0.04464243464105004)]
# ...

# %%
white=topic_model.find_topics("white")

# %%
for idx,topic in enumerate(white[0]):
  print("topic", topic,topic_model.get_topic(topic))
# Out:
# topic 0 [('white', 0.025539998527906033), ('people', 0.018080907076892125), ('land', 0.005921623203356127), ('not', 0.005514862258073617), ('do', 0.005407043400495442), ('merchandise', 0.005201414589654144), ('our', 0.00506465734880076), ('thought', 0.005015354957985888), ('words', 0.004987391906876237), ('forest', 0.004985342637191813)]
# topic 72 [('xapiri', 0.025180187528779985), ('white', 0.02110763744198334), ('land', 0.019213800830247287), ('people', 0.01504037699001139), ('ecology', 0.013607458043598076), ('xirianá', 0.011791886411150738), ('know', 0.011240092341968926), ('ancestors', 0.009062631089724132), ('even', 0.008866515292970362), ('if', 0.00856130563630528)]
# ...

# %%
yanomami=topic_model.find_topics("yanomami")
for idx,topic in enumerate(yanomami[0]):
  print("topic", topic,topic_model.get_topic(topic))
# Out:
# topic 5 [('yanomami', 0.033454336341565354), ('western', 0.009751219700289616), ('among', 0.007584043325905953), ('refer', 0.006147372186711226), ('language', 0.005805585370627211), ('social', 0.00577932781706965), ('see', 0.005401855121990381), ('lizot', 0.0053518923411634885), ('yano', 0.005233013219781023), ('or', 0.005165657913957252)]
# topic 35 [('migliazza', 0.22331585008940377), ('capobianco', 0.19567161513503256), ('andujar', 0.19385798598214365), ('veronesi', 0.18303063499150585), ('guimarães', 0.17407034631348994), ('neel', 0.1671268580763391), ('baugh', 0.10865131579485214), ('tsuda', 0.10865131579485214), ('cyanocompsa', 0.10865131579485214), ('echavarria', 0.10865131579485214)]
# ...

# %%
gold=topic_model.find_topics("gold")
for idx,topic in enumerate(gold[0]):
  print("topic", topic,topic_model.get_topic(topic))
# Out:
# topic 17 [('gold', 0.06718003754867768), ('prospectors', 0.06629560208525447), ('ranchers', 0.014782242678294965), ('cattle', 0.014349452723686687), ('camp', 0.012632567357118719), ('prospector', 0.010256727420373696), ('prospecting', 0.009884511699616412), ('263', 0.009322487963440278), ('466', 0.009224563614352409), ('262', 0.007330980298903838)]
# topic 54 [('gold', 0.05734987544235185), ('prospectors', 0.045636821031415066), ('territory', 0.027131993294025773), ('yanomami', 0.024596394488258302), ('rush', 0.023863152727868812), ('invasion', 0.02189901918635555), ('1980s', 0.020229537275105017), ('late', 0.0189588307909125), ('prospecting', 0.015642156561682535), ('brazil', 0.014797746361496613)]
# ...

# %%
xapiri=topic_model.find_topics("xapiri")
for idx,topic in enumerate(xapiri[0]):
  print("topic", topic,topic_model.get_topic(topic))
# Out:
# topic 13 [('xapiri', 0.04619389413099092), ('away', 0.009145122107362728), ('can', 0.009066404567307762), ('numbers', 0.008063353162713182), ('us', 0.007804428444176646), ('slow', 0.007479387433823693), ('cure', 0.006916672032615084), ('paths', 0.006838335125226033), ('not', 0.0066730969266563045), ('dangerous', 0.006650036003909937)]
# topic 15 [('xawara', 0.06915367417665962), ('epidemic', 0.05066580167411635), ('xawarari', 0.037579362936100716), ('beings', 0.017593543708415874), ('epidemics', 0.015495087766660956), ('smoke', 0.012253344846095667), ('fumes', 0.01062900994520095), ('devour', 0.010471588918627619), ('fight', 0.009914278210037049), ('xawala', 0.008991527170349763)]
# ...
